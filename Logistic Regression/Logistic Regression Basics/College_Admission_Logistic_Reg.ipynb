# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the dataset :

# %%
raw_data = pd.read_csv('Admittance_Sheet.csv')
raw_data.head()
# Out:
#     SAT Admitted
# 0  1363       No
# 1  1792      Yes
# 2  1954      Yes
# 3  1653       No
# 4  1593       No

# %%
data = raw_data.copy()
data['Admitted'] = data['Admitted'].map({'Yes':1,'No':0})
data.head()
# Out:
#     SAT  Admitted
# 0  1363         0
# 1  1792         1
# 2  1954         1
# 3  1653         0
# 4  1593         0

# %%
y = data['Admitted']
x1 = data['SAT']

# %%
plt.scatter(x1,y,color='C0')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('Admitted',fontsize=20)
plt.show()

# %% [markdown]
# ### Plot with a regression line

# %%
x = sm.add_constant(x1)
reg_lin = sm.OLS(y,x)
results_lin = reg_lin.fit()

plt.scatter(x1,y,color='C0')
yhat = x1*results_lin.params[1] + results_lin.params[0]

plt.plot(x1,yhat,lw=2.5,color = 'C8' )
plt.xlabel('SAT',fontsize=20)
plt.ylabel('Admitted',fontsize=20)
plt.show()

# %%
reg_log = sm.Logit(y,x)
results_log = reg_log.fit()

def f(x,b0,b1):
    return np.array(np.exp(b0+x*b1) / (1 + np.exp(b0+x*b1)))

f_sorted = np.sort(f(x1,results_log.params[0],results_log.params[1]))
x_sorted = np.sort(np.array(x1))

plt.plot(x1,y,color = 'C0' )
plt.xlabel('SAT',fontsize=20)
plt.ylabel('Admitted',fontsize=20)
plt.plot(x_sorted, f_sorted, color = 'C8')
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.137766
#          Iterations 10

# %% [markdown]
# # Logistic Regression :

# %%
x = sm.add_constant(x1)
reg_log = sm.Logit(y,x)
results_log = reg_log.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.137766
#          Iterations 10

# %% [markdown]
# ### Summary -

# %%
#import a fix to the statsmodels lib for summary()
from scipy import stats
stats.chisqprob = lambda chisq, df : stats.chi2.sf(chisq,df)

# %%
results_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      166
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 16 Jul 2020   Pseudo R-squ.:                  0.7992
# Time:                        16:48:18   Log-Likelihood:                -23.145
# converged:                       True   LL-Null:                       -115.26
#                                         LLR p-value:                 5.805e-42
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -69.9128     15.737     -4.443      0.000    -100.756     -39.070
# SAT            0.0420      0.009      4.454      0.000       0.024       0.060
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.27 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %% [markdown]
#  ## Binary Predictions

# %%
raw_data = pd.read_csv('Binary_predictors.csv')
raw_data.head()
# Out:
#     SAT Admitted  Gender
# 0  1363       No    Male
# 1  1792      Yes  Female
# 2  1954      Yes  Female
# 3  1653       No    Male
# 4  1593       No    Male

# %%
data = raw_data.copy()
data['Admitted'] = data['Admitted'].map({'Yes':1,'No':0})
data['Gender']=data['Gender'].map({'Female':1,'Male':0})
data.head()
# Out:
#     SAT  Admitted  Gender
# 0  1363         0       0
# 1  1792         1       1
# 2  1954         1       1
# 3  1653         0       0
# 4  1593         0       0

# %%
y = data['Admitted']
x1 = data['Gender']

# %%
x=sm.add_constant(x1)
reg_log = sm.Logit(y,x)
results_log = reg_log.fit()
results_log.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.572260
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      166
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 16 Jul 2020   Pseudo R-squ.:                  0.1659
# Time:                        20:30:43   Log-Likelihood:                -96.140
# converged:                       True   LL-Null:                       -115.26
#                                         LLR p-value:                 6.283e-10
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6436      0.222     -2.901      0.004      -1.078      -0.209
# Gender         2.0786      0.363      5.727      0.000       1.367       2.790
# ==============================================================================
# """

# %%
#Odds of female = 2.08 * Odds of male
np.exp(2.0786)
# Out:
# 7.993270498536442

# %%
y = data['Admitted']
x1 = data[['SAT','Gender']]

# %%
x=sm.add_constant(x1)
reg_log = sm.Logit(y,x)
results_log = reg_log.fit()
results_log.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.120117
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      165
# Method:                           MLE   Df Model:                            2
# Date:                Thu, 16 Jul 2020   Pseudo R-squ.:                  0.8249
# Time:                        20:31:38   Log-Likelihood:                -20.180
# converged:                       True   LL-Null:                       -115.26
#                                         LLR p-value:                 5.118e-42
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -68.3489     16.454     -4.154      0.000    -100.598     -36.100
# SAT            0.0406      0.010      4.129      0.000       0.021       0.060
# Gender         1.9449      0.846      2.299      0.022       0.287       3.603
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.27 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
np.exp(1.9449)
# Out:
# 6.992932526814459

# %% [markdown]
# ## Accuracy :

# %%
#Predicted values to check accuracy
np.set_printoptions(formatter = {'float':lambda x:'{0:0.02f}'.format(x)})
results_log.predict()
# Out:
# array([0.00, 1.00, 1.00, 0.23, 0.02, 0.99, 1.00, 1.00, 1.00, 0.01, 1.00,
#        1.00, 0.76, 0.00, 0.60, 1.00, 0.11, 0.12, 0.51, 1.00, 1.00, 1.00,
#        0.00, 0.01, 0.97, 1.00, 0.48, 0.99, 1.00, 0.99, 0.00, 0.83, 0.25,
#        1.00, 1.00, 1.00, 0.31, 1.00, 0.23, 0.00, 0.02, 0.45, 1.00, 0.00,
#        0.99, 0.00, 0.99, 0.00, 0.00, 0.01, 0.00, 1.00, 0.92, 0.02, 1.00,
#        0.00, 0.37, 0.98, 0.12, 1.00, 0.00, 0.78, 1.00, 1.00, 0.98, 0.00,
#        0.00, 0.00, 1.00, 0.00, 0.78, 0.12, 0.00, 0.99, 1.00, 1.00, 0.00,
#        0.30, 1.00, 1.00, 0.00, 1.00, 1.00, 0.85, 1.00, 1.00, 0.00, 1.00,
#        1.00, 0.89, 0.83, 0.00, 0.98, 0.97, 0.00, 1.00, 1.00, 0.03, 0.99,
#        0.96, 1.00, 0.00, 1.00, 0.01, 0.01, 1.00, 1.00, 1.00, 0.00, 0.00,
#        0.02, 0.33, 0.00, 1.00, 0.09, 0.00, 0.97, 0.00, 0.75, 1.00, 1.00,
#        0.01, 0.01, 0.00, 1.00, 0.00, 0.99, 0.57, 0.54, 0.87, 0.83, 0.00,
#        1.00, 0.00, 0.00, 0.00, 1.00, 0.04, 0.00, 0.01, 1.00, 0.99, 0.52,
#        1.00, 1.00, 0.05, 0.00, 0.00, 0.00, 0.68, 1.00, 1.00, 1.00, 1.00,
#        1.00, 0.00, 1.00, 1.00, 0.04, 1.00, 0.02, 1.00, 0.99, 0.97, 0.94,
#        0.01, 0.00, 0.00])

# %%
results_log.pred_table()
# Out:
# array([[69.00, 5.00],
#        [4.00, 90.00]])

# %%
#Confusion matrix:
cm_df = pd.DataFrame(results_log.pred_table())
cm_df.columns = ['Predicted 0', 'Predicted 1']
cm_df = cm_df.rename(index={0:'Actual 0',1:'Actual 1'})
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0         69.0          5.0
# Actual 1          4.0         90.0

# %% [markdown]
# #### Calculate accuracy :

# %%
cm = np.array(cm_df)
accuracy_train = (cm[0,0] + cm [1,1]) / cm.sum()
accuracy_train
# Out:
# 0.9464285714285714

# %% [markdown]
# ## Testing the model to assess acuracy

# %%
test = pd.read_csv('Test_dataset.csv')
test.head()
# Out:
#     SAT Admitted  Gender
# 0  1323       No    Male
# 1  1725      Yes  Female
# 2  1762      Yes  Female
# 3  1777      Yes    Male
# 4  1665       No    Male

# %%
test['Admitted'] = test['Admitted'].map({'Yes':1,'No':0})
test['Gender']=test['Gender'].map({'Female':1,'Male':0})
test
# Out:
#      SAT  Admitted  Gender
# 0   1323         0       0
# 1   1725         1       1
# 2   1762         1       1
# 3   1777         1       0
# 4   1665         0       0
# 5   1556         1       1
# 6   1731         1       1
# 7   1809         1       1
# 8   1930         1       1
# 9   1708         1       0
# 10  1970         1       1
# 11  2039         1       1
# 12  1681         1       1
# 13  1444         0       0
# 14  1726         0       0
# 15  1876         1       1
# 16  1485         0       0
# 17  1500         0       1
# 18  1900         1       0

# %%
x
# Out:
#      const   SAT  Gender
# 0      1.0  1363       0
# 1      1.0  1792       1
# 2      1.0  1954       1
# 3      1.0  1653       0
# 4      1.0  1593       0
# 5      1.0  1755       1
# 6      1.0  1775       1
# 7      1.0  1887       1
# 8      1.0  1893       1
# 9      1.0  1580       0
# 10     1.0  1857       1
# 11     1.0  1880       1
# 12     1.0  1664       1
# 13     1.0  1364       0
# 14     1.0  1693       0
# 15     1.0  1850       1
# 16     1.0  1633       0
# 17     1.0  1634       0
# 18     1.0  1636       1
# 19     1.0  1855       1
# 20     1.0  1987       1
# 21     1.0  1997       0
# 22     1.0  1422       1
# 23     1.0  1508       1
# 24     1.0  1720       1
# 25     1.0  1879       0
# 26     1.0  1634       1
# 27     1.0  1802       0
# 28     1.0  1849       1
# 29     1.0  1764       1
# ..     ...   ...     ...
# 138    1.0  1412       1
# 139    1.0  1557       0
# 140    1.0  1821       0
# 141    1.0  1760       1
# 142    1.0  1685       0
# 143    1.0  1773       1
# 144    1.0  1826       1
# 145    1.0  1565       1
# 146    1.0  1510       0
# 147    1.0  1374       0
# 148    1.0  1402       0
# 149    1.0  1702       0
# 150    1.0  1956       1
# 151    1.0  1933       0
# 152    1.0  1832       0
# 153    1.0  1893       0
# 154    1.0  1831       1
# 155    1.0  1487       0
# 156    1.0  2041       1
# 157    1.0  1850       0
# 158    1.0  1555       1
# 159    1.0  2020       1
# 160    1.0  1593       0
# 161    1.0  1934       1
# 162    1.0  1808       0
# 163    1.0  1722       1
# 164    1.0  1750       0
# 165    1.0  1555       0
# 166    1.0  1524       0
# 167    1.0  1461       0
#
# [168 rows x 3 columns]

# %%
test_actual = test['Admitted']
test_data = test.drop(['Admitted'],axis =1)
test_data = sm.add_constant(test_data)
test_data
# Out:
#     const   SAT  Gender
# 0     1.0  1323       0
# 1     1.0  1725       1
# 2     1.0  1762       1
# 3     1.0  1777       0
# 4     1.0  1665       0
# 5     1.0  1556       1
# 6     1.0  1731       1
# 7     1.0  1809       1
# 8     1.0  1930       1
# 9     1.0  1708       0
# 10    1.0  1970       1
# 11    1.0  2039       1
# 12    1.0  1681       1
# 13    1.0  1444       0
# 14    1.0  1726       0
# 15    1.0  1876       1
# 16    1.0  1485       0
# 17    1.0  1500       1
# 18    1.0  1900       0

# %% [markdown]
# ### Confusion matrix :

# %%
#Confusion matrix for testing :

def confusion_matrix(data,actual_values,model):
    pred_values = model.predict(data)
    bins = np.array([0,0.5,1])
    cm = np.histogram2d(actual_values, pred_values, bins = bins)[0]
    accuracy = (cm[0,0] + cm[1,1]) / cm.sum()
    return cm, accuracy

# %%
cm = confusion_matrix(test_data,test_actual,results_log)
cm
# Out:
# (array([[5.00, 1.00],
#         [1.00, 12.00]]), 0.8947368421052632)
